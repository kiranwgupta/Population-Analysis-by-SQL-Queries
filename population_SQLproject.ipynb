# %% [markdown]
# # Population Analysis by SQL Queries

# %% [markdown]
# ## Import necessary libraries

# %%
#import Libraries
import pandas as pd
import os
from pandasql import sqldf

# %% [markdown]
# ## Data Collection

# %%
#import files
df=pd.read_csv(r"C:\Users\HP-PC\Desktop\Projects\population\population.csv")
df.head()
# Out:
#    Rank           State    Capital   Population  % of Total Population  \
# 0     1   Uttar Pradesh    Lucknow  199,812,341                  16.50
# 1     2     Maharashtra     Mumbai  112,374,333                   9.28
# 2     3           Bihar      Patna  104,099,452                   8.60
# 3     4     West Bengal    Kolkata   91,276,115                   7.54
# 4     5  Andhra Pradesh  Hyderabad   84,580,777                   6.99
#
#          Males     Females Sex Ratio  Literacy Rate (%) Rural Population  \
# 0  104,480,510  95,331,831       912              67.68      155,111,022
# 1   58,243,056  54,131,277       929              82.34       61,545,441
# 2   54,278,157  49,821,295       918              61.80       92,075,028
# 3   46,809,027  44,467,088       950              76.26       62,213,676
# 4   42,442,146  42,138,631       993              67.02       56,361,702
#
#   Urban Population Area (km*km) Density (1/km*km) Decadal Growth (%)
# 0       44,470,455      240,928               828              20.1%
# 1       50,827,531      307,713               365              16.0%
# 2       11,729,609       94,163             1,102              25.1%
# 3       29,134,060       88,752             1,030              13.9%
# 4       28,219,075      275,045               308             10.98%

# %% [markdown]
# ## Data Exploration

# %%
df.shape
# Out:
# (35, 14)

# %%
df.columns
# Out:
# Index(['Rank', 'State', 'Capital', 'Population', '% of Total Population',
#        'Males', 'Females', 'Sex Ratio', 'Literacy Rate (%)',
#        'Rural Population', 'Urban Population', 'Area (km*km)',
#        'Density (1/km*km)', 'Decadal Growth (%)'],
#       dtype='object')

# %% [markdown]
# ### Check Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rank                   35 non-null     int64
#  1   State                  35 non-null     object
#  2   Capital                34 non-null     object
#  3   Population             35 non-null     object
#  4   % of Total Population  35 non-null     float64
#  5   Males                  35 non-null     object
#  6   Females                35 non-null     object
#  7   Sex Ratio              35 non-null     object
#  8   Literacy Rate (%)      35 non-null     float64
#  9   Rural Population       35 non-null     object
#  10  Urban Population       35 non-null     object
#  11  Area (km*km)           35 non-null     object
#  12  Density (1/km*km)      35 non-null     object
#  13  Decadal Growth (%)     35 non-null     object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 4.0+ KB

# %% [markdown]
# ### Correct the data type

# %%
#create function to change the object data to float
def object_to_int(data):
    df[data]=df[data].str.replace(",","")
    df[data]=df[data].str.replace("%","")
    df[data]=df[data].astype('float')

#columns
columns=["Population","Males","Females","Sex Ratio","Rural Population","Urban Population","Area (km*km)","Density (1/km*km)"]

for col in columns:
    object_to_int(col)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rank                   35 non-null     int64
#  1   State                  35 non-null     object
#  2   Capital                34 non-null     object
#  3   Population             35 non-null     float64
#  4   % of Total Population  35 non-null     float64
#  5   Males                  35 non-null     float64
#  6   Females                35 non-null     float64
#  7   Sex Ratio              35 non-null     float64
#  8   Literacy Rate (%)      35 non-null     float64
#  9   Rural Population       35 non-null     float64
#  10  Urban Population       35 non-null     float64
#  11  Area (km*km)           35 non-null     float64
#  12  Density (1/km*km)      35 non-null     float64
#  13  Decadal Growth (%)     35 non-null     object
# dtypes: float64(10), int64(1), object(3)
# memory usage: 4.0+ KB

# %% [markdown]
# ### 1.	Retrieve State and Population for States with Population above 5 crore (50 million)

# %%
task="select State, Population from df where Population > 50000000"
sqldf(task,globals())
# Out:
#             State   Population
# 0   Uttar Pradesh  199812341.0
# 1     Maharashtra  112374333.0
# 2           Bihar  104099452.0
# 3     West Bengal   91276115.0
# 4  Andhra Pradesh   84580777.0
# 5  Madhya Pradesh   72626809.0
# 6      Tamil Nadu   72147030.0
# 7       Rajasthan   68548437.0
# 8       Karnataka   61095297.0
# 9         Gujarat   60439692.0

# %% [markdown]
# ### 2.	Calculate the Average Literacy Rate and Average Density

# %%
task='SELECT AVG("Literacy Rate (%)") AS Avg_Literacy_Rate, AVG("Density (1/km*km)") AS Avg_Density FROM df'
sqldf(task,globals())
# Out:
#    Avg_Literacy_Rate  Avg_Density
# 0          77.940286  1091.885714

# %% [markdown]
# ### 3.	Find the State with the highest Male to Female Ratio:

# %%
task='SELECT State, Males, Females, "Sex Ratio" FROM df ORDER BY "Sex Ratio" DESC LIMIT 1'
sqldf(task,globals())
# Out:
#     State       Males     Females  Sex Ratio
# 0  Kerala  16027412.0  17378649.0     1084.0

# %% [markdown]
# ### 4.	Retrieve the Top 5 States with the Highest Urban Population Percentage

# %%
task='SELECT State, UrbanPopulationPercentage FROM (SELECT State, round("Urban Population" / ("Rural Population" + "Urban Population") * 100,2) AS UrbanPopulationPercentage FROM df) AS UrbanPopPercentages ORDER BY UrbanPopulationPercentage DESC LIMIT 5'
sqldf(task,globals())
# Out:
#            State  UrbanPopulationPercentage
# 0     Chandigarh                      97.25
# 1          Delhi                      93.18
# 2    Lakshadweep                      78.08
# 3  Daman and Diu                      75.16
# 4     Puducherry                      68.31

# %% [markdown]
# ### 5.	Calculate the Total Population and Area for Each Region (Rural and Urban) and Each State

# %%
task='SELECT State,SUM("Rural Population") AS Total_Rural_Population, SUM("Urban Population") AS Total_Urban_Population, SUM("Area (km*km)") AS Total_Area FROM df GROUP BY State'
sqldf(task,globals())
# Out:
#                           State  Total_Rural_Population  \
# 0   Andaman and Nicobar Islands                244411.0
# 1                Andhra Pradesh              56361702.0
# 2             Arunachal Pradesh               1069165.0
# 3                         Assam              26780526.0
# 4                         Bihar              92075028.0
# 5                    Chandigarh                 29004.0
# 6                  Chhattisgarh              19603658.0
# 7        Dadra and Nagar Haveli                183024.0
# 8                 Daman and Diu                 60331.0
# 9                         Delhi                944727.0
# 10                          Goa                551414.0
# 11                      Gujarat              34670817.0
# 12                      Haryana              16531493.0
# 13             Himachal Pradesh               6167805.0
# 14            Jammu and Kashmir               9134820.0
# 15                    Jharkhand              25036946.0
# 16                    Karnataka              37552529.0
# 17                       Kerala              17445506.0
# 18                  Lakshadweep                 14121.0
# 19               Madhya Pradesh              52537899.0
# 20                  Maharashtra              61545441.0
# 21                      Manipur               1899624.0
# 22                    Meghalaya               2368971.0
# 23                      Mizoram                529037.0
# 24                     Nagaland               1406861.0
# 25                       Odisha              34951234.0
# 26                   Puducherry                394341.0
# 27                       Punjab              17316800.0
# 28                    Rajasthan              51540236.0
# 29                       Sikkim                455962.0
# 30                   Tamil Nadu              37189229.0
# 31                      Tripura               2710051.0
# 32                Uttar Pradesh             155111022.0
# 33                  Uttarakhand               7025583.0
# 34                  West Bengal              62213676.0
#
#     Total_Urban_Population  Total_Area
# 0                 135533.0      8249.0
# 1               28219075.0    275045.0
# 2                 313446.0     83743.0
# 3                4388756.0     78438.0
# 4               11729609.0     94163.0
# 5                1025682.0       114.0
# 6                5936538.0    135191.0
# 7                 159829.0       491.0
# 8                 182580.0       112.0
# 9               12905780.0      1484.0
# 10                906309.0      3702.0
# 11              25712811.0    196024.0
# 12               8821588.0     44212.0
# 13                688704.0     55673.0
# 14               3414106.0    222236.0
# 15               7929292.0     79714.0
# 16              23578175.0    191791.0
# 17              15932171.0     38863.0
# 18                 50308.0        32.0
# 19              20059666.0    308245.0
# 20              50827531.0    307713.0
# 21                822132.0     22327.0
# 22                595036.0     22429.0
# 23                561997.0     21081.0
# 24                573741.0     16579.0
# 25               6996124.0    155707.0
# 26                850123.0       479.0
# 27              10387436.0     50362.0
# 28              17080776.0    342239.0
# 29                151726.0      7096.0
# 30              34949729.0    130058.0
# 31                960981.0     10486.0
# 32              44470455.0    240928.0
# 33               3091169.0     53483.0
# 34              29134060.0     88752.0

# %% [markdown]
# ### 6.	Find the States with a Literacy Rate above the National Average Literacy Rate

# %%
task='SELECT State, "Literacy Rate (%)" FROM df WHERE "Literacy Rate (%)" > (SELECT AVG("Literacy Rate (%)") FROM df)'
sqldf(task,globals())
# Out:
#                           State  Literacy Rate (%)
# 0                   Maharashtra              82.34
# 1                    Tamil Nadu              80.09
# 2                       Gujarat              78.03
# 3                        Kerala              94.00
# 4                         Delhi              86.21
# 5                   Uttarakhand              79.63
# 6              Himachal Pradesh              82.80
# 7                       Tripura              87.22
# 8                       Manipur              79.21
# 9                      Nagaland              79.55
# 10                          Goa              88.70
# 11                   Puducherry              85.85
# 12                      Mizoram              91.33
# 13                   Chandigarh              86.05
# 14                       Sikkim              81.42
# 15  Andaman and Nicobar Islands              86.63
# 16                Daman and Diu              87.10
# 17                  Lakshadweep              91.85

# %% [markdown]
# ### 7.	Retrieve the Capital and Population for the 3 Most Populated States

# %%
task='SELECT Capital, Population FROM df ORDER BY Population DESC LIMIT 3'
sqldf(task,globals())
# Out:
#    Capital   Population
# 0  Lucknow  199812341.0
# 1   Mumbai  112374333.0
# 2    Patna  104099452.0

# %% [markdown]
# ### 8.	Calculate the average population of states

# %%
#task='SELECT State, AVG(Population) OVER () AS avg_population FROM df'
task='SELECT State, AVG(Population) AS avg_population FROM df'
sqldf(task,globals())
# Out:
#            State  avg_population
# 0  Uttar Pradesh    3.459203e+07

# %% [markdown]
# ### 9.	Rank states by population

# %%
task='SELECT Rank, State, Population, RANK() OVER (ORDER BY Population DESC) AS population_rank FROM df'
sqldf(task,globals())
# Out:
#     Rank                        State   Population  population_rank
# 0      1                Uttar Pradesh  199812341.0                1
# 1      2                  Maharashtra  112374333.0                2
# 2      3                        Bihar  104099452.0                3
# 3      4                  West Bengal   91276115.0                4
# 4      5               Andhra Pradesh   84580777.0                5
# 5      6               Madhya Pradesh   72626809.0                6
# 6      7                   Tamil Nadu   72147030.0                7
# 7      8                    Rajasthan   68548437.0                8
# 8      9                    Karnataka   61095297.0                9
# 9     10                      Gujarat   60439692.0               10
# 10    11                       Odisha   41974218.0               11
# 11    12                       Kerala   33406061.0               12
# 12    13                    Jharkhand   32988134.0               13
# 13    14                        Assam   31205576.0               14
# 14    15                       Punjab   27743338.0               15
# 15    16                 Chhattisgarh   25545198.0               16
# 16    17                      Haryana   25351462.0               17
# 17    18                        Delhi   16787941.0               18
# 18    19            Jammu and Kashmir   12541302.0               19
# 19    20                  Uttarakhand   10086292.0               20
# 20    21             Himachal Pradesh    6864602.0               21
# 21    22                      Tripura    3673917.0               22
# 22    23                    Meghalaya    2966889.0               23
# 23    24                      Manipur    2721756.0               24
# 24    25                     Nagaland    1978502.0               25
# 25    26                          Goa    1458545.0               26
# 26    27            Arunachal Pradesh    1383727.0               27
# 27    28                   Puducherry    1247953.0               28
# 28    29                      Mizoram    1097206.0               29
# 29    30                   Chandigarh    1055450.0               30
# 30    31                       Sikkim     610577.0               31
# 31    32  Andaman and Nicobar Islands     380581.0               32
# 32    33       Dadra and Nagar Haveli     343709.0               33
# 33    34                Daman and Diu     243247.0               34
# 34    35                  Lakshadweep      64473.0               35

# %% [markdown]
# ### 10.	Calculate the population share percentage for each state

# %%
task='SELECT State, Population, (Population / SUM(Population) OVER ()) * 100 AS population_share_percentage FROM df'
sqldf(task,globals())
# Out:
#                           State   Population  population_share_percentage
# 0                 Uttar Pradesh  199812341.0                    16.503583
# 1                   Maharashtra  112374333.0                     9.281605
# 2                         Bihar  104099452.0                     8.598138
# 3                   West Bengal   91276115.0                     7.538989
# 4                Andhra Pradesh   84580777.0                     6.985984
# 5                Madhya Pradesh   72626809.0                     5.998642
# 6                    Tamil Nadu   72147030.0                     5.959014
# 7                     Rajasthan   68548437.0                     5.661787
# 8                     Karnataka   61095297.0                     5.046191
# 9                       Gujarat   60439692.0                     4.992042
# 10                       Odisha   41974218.0                     3.466878
# 11                       Kerala   33406061.0                     2.759188
# 12                    Jharkhand   32988134.0                     2.724669
# 13                        Assam   31205576.0                     2.577438
# 14                       Punjab   27743338.0                     2.291473
# 15                 Chhattisgarh   25545198.0                     2.109916
# 16                      Haryana   25351462.0                     2.093915
# 17                        Delhi   16787941.0                     1.386607
# 18            Jammu and Kashmir   12541302.0                     1.035854
# 19                  Uttarakhand   10086292.0                     0.833081
# 20             Himachal Pradesh    6864602.0                     0.566985
# 21                      Tripura    3673917.0                     0.303449
# 22                    Meghalaya    2966889.0                     0.245051
# 23                      Manipur    2721756.0                     0.224805
# 24                     Nagaland    1978502.0                     0.163415
# 25                          Goa    1458545.0                     0.120469
# 26            Arunachal Pradesh    1383727.0                     0.114290
# 27                   Puducherry    1247953.0                     0.103075
# 28                      Mizoram    1097206.0                     0.090624
# 29                   Chandigarh    1055450.0                     0.087175
# 30                       Sikkim     610577.0                     0.050431
# 31  Andaman and Nicobar Islands     380581.0                     0.031434
# 32       Dadra and Nagar Haveli     343709.0                     0.028389
# 33                Daman and Diu     243247.0                     0.020091
# 34                  Lakshadweep      64473.0                     0.005325

# %% [markdown]
# ### 11.	Calculate the cumulative population percentage using window function

# %%
task='SELECT State,Population,SUM(Population) OVER (ORDER BY Population DESC) AS cumulative_population,(SUM(Population) OVER (ORDER BY Population DESC) / SUM(Population) OVER ()) * 100 AS cumulative_population_percentage FROM df'
sqldf(task,globals())
# Out:
#                           State   Population  cumulative_population  \
# 0                 Uttar Pradesh  199812341.0           1.998123e+08
# 1                   Maharashtra  112374333.0           3.121867e+08
# 2                         Bihar  104099452.0           4.162861e+08
# 3                   West Bengal   91276115.0           5.075622e+08
# 4                Andhra Pradesh   84580777.0           5.921430e+08
# 5                Madhya Pradesh   72626809.0           6.647698e+08
# 6                    Tamil Nadu   72147030.0           7.369169e+08
# 7                     Rajasthan   68548437.0           8.054653e+08
# 8                     Karnataka   61095297.0           8.665606e+08
# 9                       Gujarat   60439692.0           9.270003e+08
# 10                       Odisha   41974218.0           9.689745e+08
# 11                       Kerala   33406061.0           1.002381e+09
# 12                    Jharkhand   32988134.0           1.035369e+09
# 13                        Assam   31205576.0           1.066574e+09
# 14                       Punjab   27743338.0           1.094318e+09
# 15                 Chhattisgarh   25545198.0           1.119863e+09
# 16                      Haryana   25351462.0           1.145214e+09
# 17                        Delhi   16787941.0           1.162002e+09
# 18            Jammu and Kashmir   12541302.0           1.174544e+09
# 19                  Uttarakhand   10086292.0           1.184630e+09
# 20             Himachal Pradesh    6864602.0           1.191494e+09
# 21                      Tripura    3673917.0           1.195168e+09
# 22                    Meghalaya    2966889.0           1.198135e+09
# 23                      Manipur    2721756.0           1.200857e+09
# 24                     Nagaland    1978502.0           1.202835e+09
# 25                          Goa    1458545.0           1.204294e+09
# 26            Arunachal Pradesh    1383727.0           1.205678e+09
# 27                   Puducherry    1247953.0           1.206926e+09
# 28                      Mizoram    1097206.0           1.208023e+09
# 29                   Chandigarh    1055450.0           1.209078e+09
# 30                       Sikkim     610577.0           1.209689e+09
# 31  Andaman and Nicobar Islands     380581.0           1.210070e+09
# 32       Dadra and Nagar Haveli     343709.0           1.210413e+09
# 33                Daman and Diu     243247.0           1.210656e+09
# 34                  Lakshadweep      64473.0           1.210721e+09
#
#     cumulative_population_percentage
# 0                          16.503583
# 1                          25.785188
# 2                          34.383326
# 3                          41.922315
# 4                          48.908299
# 5                          54.906941
# 6                          60.865955
# 7                          66.527741
# 8                          71.573933
# 9                          76.565974
# 10                         80.032852
# 11                         82.792040
# 12                         85.516708
# 13                         88.094146
# 14                         90.385619
# 15                         92.495535
# 16                         94.589449
# 17                         95.976056
# 18                         97.011910
# 19                         97.844992
# 20                         98.411977
# 21                         98.715425
# 22                         98.960477
# 23                         99.185281
# 24                         99.348696
# 25                         99.469166
# 26                         99.583455
# 27                         99.686530
# 28                         99.777155
# 29                         99.864330
# 30                         99.914761
# 31                         99.946195
# 32                         99.974584
# 33                         99.994675
# 34                        100.000000

# %% [markdown]
# ### 12.	Calculate the difference in population from the previous state

# %%
task='select State, Population, lag(Population) over(order by rank) as "Previous Population",Population-lag(Population) over(order by rank) as "Population Difference" from df'
sqldf(task,globals())
# Out:
#                           State   Population  Previous Population  \
# 0                 Uttar Pradesh  199812341.0                  NaN
# 1                   Maharashtra  112374333.0          199812341.0
# 2                         Bihar  104099452.0          112374333.0
# 3                   West Bengal   91276115.0          104099452.0
# 4                Andhra Pradesh   84580777.0           91276115.0
# 5                Madhya Pradesh   72626809.0           84580777.0
# 6                    Tamil Nadu   72147030.0           72626809.0
# 7                     Rajasthan   68548437.0           72147030.0
# 8                     Karnataka   61095297.0           68548437.0
# 9                       Gujarat   60439692.0           61095297.0
# 10                       Odisha   41974218.0           60439692.0
# 11                       Kerala   33406061.0           41974218.0
# 12                    Jharkhand   32988134.0           33406061.0
# 13                        Assam   31205576.0           32988134.0
# 14                       Punjab   27743338.0           31205576.0
# 15                 Chhattisgarh   25545198.0           27743338.0
# 16                      Haryana   25351462.0           25545198.0
# 17                        Delhi   16787941.0           25351462.0
# 18            Jammu and Kashmir   12541302.0           16787941.0
# 19                  Uttarakhand   10086292.0           12541302.0
# 20             Himachal Pradesh    6864602.0           10086292.0
# 21                      Tripura    3673917.0            6864602.0
# 22                    Meghalaya    2966889.0            3673917.0
# 23                      Manipur    2721756.0            2966889.0
# 24                     Nagaland    1978502.0            2721756.0
# 25                          Goa    1458545.0            1978502.0
# 26            Arunachal Pradesh    1383727.0            1458545.0
# 27                   Puducherry    1247953.0            1383727.0
# 28                      Mizoram    1097206.0            1247953.0
# 29                   Chandigarh    1055450.0            1097206.0
# 30                       Sikkim     610577.0            1055450.0
# 31  Andaman and Nicobar Islands     380581.0             610577.0
# 32       Dadra and Nagar Haveli     343709.0             380581.0
# 33                Daman and Diu     243247.0             343709.0
# 34                  Lakshadweep      64473.0             243247.0
#
#     Population Difference
# 0                     NaN
# 1             -87438008.0
# 2              -8274881.0
# 3             -12823337.0
# 4              -6695338.0
# 5             -11953968.0
# 6               -479779.0
# 7              -3598593.0
# 8              -7453140.0
# 9               -655605.0
# 10            -18465474.0
# 11             -8568157.0
# 12              -417927.0
# 13             -1782558.0
# 14             -3462238.0
# 15             -2198140.0
# 16              -193736.0
# 17             -8563521.0
# 18             -4246639.0
# 19             -2455010.0
# 20             -3221690.0
# 21             -3190685.0
# 22              -707028.0
# 23              -245133.0
# 24              -743254.0
# 25              -519957.0
# 26               -74818.0
# 27              -135774.0
# 28              -150747.0
# 29               -41756.0
# 30              -444873.0
# 31              -229996.0
# 32               -36872.0
# 33              -100462.0
# 34              -178774.0
